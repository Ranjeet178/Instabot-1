# %% [markdown]
# 1. Login to your Instagram Handle
#
#      1.Submit with sample username and password

# %%
from selenium import webdriver                                    #importing webdriver
from selenium.webdriver.support.ui import WebDriverWait           #To use implcit and explicit wait
from selenium.webdriver.support import expected_conditions as EC  #use in explicitly wait
from selenium.webdriver.common.by import By                       #to select the attribute by Class,link_text
from selenium.webdriver.support.ui import Select
import time
from bs4 import BeautifulSoup                                              #work with attribute 
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException  #to handle StaleElementReferenceException
from selenium.webdriver.common.keys import Keys #For navigating the pop up window
from selenium.common.exceptions import NoSuchElementException #to handle NoSuchElementException

# %%
driver=webdriver.Chrome(executable_path='C:/Users/singh/chromedriver') #path of 
driver.get('https://www.instagram.com/') #navigating to the instagram log in page
wait = WebDriverWait(driver, 10)
name= wait.until(EC.presence_of_element_located((By.NAME,'username'))) #locating the box to insert name of the user
name.send_keys('sample_username') # passing username
pas=driver.find_element_by_name('password') # locating the box to insert the password of the user
pas.send_keys('sample_password') #passinf password
login=driver.find_element_by_class_name('L3NKy') #serch for login button
login.click() #clicking on the login button

# %% [markdown]
# 2. Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#    1. Note : Make sure to avoid printing hashtags

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("food")                                                #sending values for searching
time.sleep(3)
val=driver.find_elements_by_xpath('//div[@class = "fuqBx"]/a["href"]')  #fetching food list Handles 
food=[] #creating an empty list for appending the list of food handlers
for i in val:
    if 'explore' in i.get_attribute('href'):        #if explore present in link then it is hastags
        continue
    else:
        s = i.get_attribute('href').split('/')      #https://www.instagram.com/foodtalkindia
        print(s[3])                                     # after split s= ['https:','','www.instagram.com','stockholmfood']
        food.append(s[3])                          #appending s[3] in food_list       
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')  #seaeching  input box 
a.clear() #clearing the input  box
b=driver.find_element_by_class_name('coreSpriteSearchClear').click() #selecting clear box by class name and clicking it
# Out:
# sailusfood
# yourfoodlab
# delhifoodwalks
# delhifoodguide
# foodie_incarnate
# foodnetwork
# food
# foodtechsimplified
# food_techies
# chennaifoodtrails
# foodporn
# wirallyfood
# foodtechnologist_corner
# food.clickz
# foodtechsociety
# tripfun.food
# foodiemee5
# foodtalkindia
# fnm_world
# foodies_scrollpoint
# delhifoodnest
# foodlover4194
# foodbible
# bangalorefoodbomb
# thefoodranger
# foodtechnologi
# healthy.foodyss
# foodbeast
# madrasfoodjournal
# foodiez_choice
# dilsefoodie
# food.darzee
# foodparadise.in
# foodnetworkasia
# ndtv_food
# food.spy.ir
# freefoodindia
# we_the_foodie
# jogjafoodhunter
# foodyeating
# foodinsider
# netflixfood
# fao
# ace._photography
# halalfoodiemy

# %% [markdown]
# 3. Searching and Opening a profile using
#
#   A. Open profile of “So Delhi”

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("So Delhi")                                              #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting so delhi
b.click() #clicking it to move to the profile of so delhi
a=driver.find_element_by_class_name('coreSpriteSearchClear') #selecting clear box by class name
a.click()

# %%
driver.back()

# %% [markdown]
# 4. Follow/Unfollow given handle -
#
#    A. Open the Instagram Handle of “So Delhi”

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("So Delhi")                                              #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting so delhi
b.click() #clicking it to open  the profile of "so delhi"

# %% [markdown]
# B.Start following it. Print a message if you are already following

# %%
follow= wait.until(EC.presence_of_element_located((By.XPATH,'//span[contains(@class,"vBF20")]/button')))  #locating the follow button
if follow.text.strip() == 'Follow':      #checking if the status is following or not
    follow.click() #if not following clicking on the follow button
else:
   print("you are already a follower of this account")    #printing you are not a follower

# %% [markdown]
# C. After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
if follow.text.strip()!='Follow': #checking if the status is following or not
    unfollow=wait.until(EC.presence_of_element_located((By.XPATH,'//span[contains(@class,"vBF20")]/button')))  #locating and clicking following button
    unfollow.click()
    unfollow=wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class,"mt3GC")]/button'))) #locating the unfollow button
    unfollow.click() #clicking the unfollow button
else:
    print("you are already not a follower of this account") #printing if you are not following this account.

# %%
z556c

# %% [markdown]
# 5. Like/Unlike posts
#
#     A. Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have

# %%
driver.back() #navigating back to the home page

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("dilsefoodie")                                              #sending values for searching
d=wait.until(EC.presence_of_element_located((By.CLASS_NAME,'z556c')))            #searching dilsefoodie profile  
d.click()                                                                     #clicking on profile
for i in range(3):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')        #infirst scroll we get 12 post so we making 3
    time.sleep(2)                                     
post = driver.find_elements_by_xpath('//div[contains(@class,"v1Nh3")]')            #finding post 
count = 1
for i in post:
    if count >30: 
         break
    i.click()  #clicking the post
    like_btn = wait.until(EC.presence_of_element_located((By.XPATH,'//span[contains(@class,"fr66n")]/button'))) #locating like button
    data=BeautifulSoup(driver.page_source,'lxml') #reading and parsing data using beautifulsoap
    chk_like=data.find(class_='fr66n') #locating the class for checking whether it is like or not
    if chk_like.button.svg['aria-label']=='Unlike': #if it is "unlike" then you already liked the post
        print("you already liked the post no.",count,"Post")#for like button
    else:
        like_btn.click() 
    close_btn = wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class,"BI4qX")]/button'))) # post close button
    close_btn.click()                                                              #click on close utton
    time.sleep(1)
    count += 1

# %% [markdown]
# B. Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
count = 1
for i in post:
    if count >30: 
         break
    i.click() 
    like_btn = wait.until(EC.presence_of_element_located((By.XPATH,'//span[contains(@class,"fr66n")]/button')))
    data=BeautifulSoup(driver.page_source,'lxml') #reading and parsing data using beautifulsoap
    chk_like=data.find(class_='fr66n') #locating the class for checking whether it is like or not
    if chk_like.button.svg['aria-label']=='Unlike': #if it is "unlike" then you already liked the post
        like_btn.click()
       
    else:
        print("you already unliked the post no.",count,"Post")#for like button    
    close_btn = wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class,"BI4qX")]/button'))) # locating post close button
    close_btn.click()         #clicking on close utton
    time.sleep(1)
    count += 1   #counting number of post

# %% [markdown]
# 6. Extract list of followers
#
# A. Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("foodtalkindia")                                              #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting foodtalkindia
b.click() #clicking it to open  the profile of "foodtalkindia"

followers_button = wait.until(EC.presence_of_element_located((By.XPATH,'//a[contains(@class,"-nal3")]'))) #follower button search
followers_button.click()   #click on followers button
time.sleep(3)
while True:
    f= driver.find_element_by_class_name('isgrP') #locating the #follower page
    f.click()
    driver.find_element_by_tag_name('body').send_keys(Keys.END) #moving end of document 
    follower= driver.find_elements_by_xpath('//div[@class = "isgrP"]/ul/div/li') #follower list
    if len(follower)>=500: #checking whether the count is greated then 500 or not
        break

li = []
j=0
foodtalkindia= [] #empty list to store the user names
for i in follower:                                                                  
    data = BeautifulSoup(i.get_attribute('innerHTML'),'html')                         #to get the name of follower             
    li.append(data.a['href'].split('/')[1])                                           #adding name in list
    foodtalkindia.append(data.a['href'].split('/')[1])
    j+=1
    if j==500:                                                                        #only top 500 follower
        break
for i in foodtalkindia:
    print(i) #printing all the names
# Out:
# wedesignco
# acan68131
# tg2188967
# from_aleeshas_pan
# sg5.4321
# pallavi.mukherjee28
# halabbaklava
# nujhat_richie
# food_ie_bae
# sumit_jha001
# foodist07
# foodstoriesbyeram
# ranju1722
# ___foodiess____
# nowhere_refound
# ty_rishi_tadvi_461
# karanjha410
# jcdsbarbequesince1947
# sandcastles_in_the_sky_
# nishthaparshwal
# neelam5784
# su._.dha
# foodtrail._
# lilac.lyra
# sid_muley
# _yourcredence
# socialdigitl.in
# devarsha1703
# ani_ani_006
# pupz_creations
# noidaexpress
# priya_food_prism
# irashabazaar
# travelwithsuhit
# gufranzayn
# withfdelya
# shahbazsanadi
# vee.cooking
# sara_jagnani
# archanaja
# riyasharma1028
# zoha_ahm
# silkykitchenlife
# haryana_vibe
# sudarshan00007
# __miss05singh__
# vanshbhati_2444
# chefsashi_83
# itz_faizan_malik_xx
# _talesoffood_
# e_x_p_l_o_r_e__india
# clickalmost
# p_nipa_dryfruits_and_groceries
# foodie_girl37
# nitinartworld
# manoj9579yadav
# deltavistaindia
# harshitagoswami712
# cravings_lovers
# bahoq_
# mr.samkit_jain
# justfoodandyou
# photo_poses_girl_78
# shinchan_lover_830
# sainathdhope
# shadijordanfortheloveofcooking
# salim_er_5
# heart_shadess
# pastrychef.kaushik
# vkuldeep282
# laibashaikh237
# soheb9178
# sonamcchhabra
# shibanibawa
# _dhraj_
# simply_unique_1
# secretpizza2021
# _sparkling_lights
# sweetpriyasingh1900
# ourkitchen.life
# chimkandi792
# khalish1985
# mr_perfect_arbaz
# foodographybyvipin
# fooodiewoodie
# tuhin07bd
# foodie_girl1010
# hotelmahesh.kalina
# thakumarrannaghor
# samkit.sethia
# roopverma29
# official_bish9ii_29
# mr._foodie_
# launchyourgenius
# thiscrazypiggy
# prashant.malhotra
# manthenaflims3784
# super_meoww
# malachitepr
# vineeth_vista
# speaker_daniel_earney
# sevalintarifleri
# meenakshi_antil
# tastehighway
# saikumar5132x
# shantha7838
# rajshukla8846
# vr.foodie
# hari_nilesh
# nitinsinghbalyan
# prepared.with.love
# _kxvya_
# simrankaurchhabda
# human.being001
# rameshmaharaja
# jack_theblackbeauty
# beingriaa
# shivangigaba_official_
# muralidhar4sai
# sahnvaz_kash_
# _gastronomiac
# __ashana.m
# dr.tech_info
# sherinchristy1
# golu_76
# vishi_001
# krish.0307
# petuk_sentrum
# chintan2886
# anup.bhatnagar.73
# _____snehaaa_____
# shubham_tekade17_official
# kajalapandya
# rohitrkreal
# manjeetpatel10
# cookingkingpro
# divyan137
# indigifts
# indishh.dotell_dehradun
# ayranouf
# sachin_dalavi_
# dip_ansh_u
# rajputana00021
# marioekka
# therocklll
# imtiyazshaikh724
# artiagrawal21
# food_lover_q
# welovespecialplaces
# sahil_tak00
# sourcegoodfood
# ira_calcutta
# varchana_
# rohot1494
# hey__ansh
# poonamjalui
# operationyummy
# bearded.yaga
# truth_that_matters_
# aru_kakkar
# born__kaur
# andrehbritton
# notso2414
# manideepsarapu
# akash.master
# shubham._abdule
# mehulsatra
# ruhiarora6224
# foodlover_5687
# iamwellandgoodeepak
# smitabasak6
# goldensingh441
# amarjeet.saluja.7146
# kamalesh6014
# nutritionistsunanda
# kabhiikhushiikabhiigham
# sarcastic.things__
# ranjithkr94
# crispy_kuku
# lokesh.gurjar.official
# amanyaprism
# bertilda_0
# market_rate_
# shobhitkumarofficial
# prammuspatisserie
# joinfoodfactory
# sanchyeetamazumder
# ankitamalhotra23
# irfanfiros____
# bashuriwala_sweets
# gin_and_tonic89
# thenomnomeaters
# ranjit8445
# sanket_gaikwad1234
# srihari2608
# easycooking_easybaking_
# modiscafe
# anurai367
# fooodddieeee
# dr.k.k.s.chakracarthy_ms
# patil.azhar
# delicacy_voyage
# gastronomic2021
# _22devika
# sandra_chirakkal
# ahnhassan9
# riya9953711
# sahusushma621
# pubg_boy_anurag
# anime.esh
# the_central_foodie
# noor10bakshi
# seems_94
# sowbernikasharan
# knife_and_forks
# srishti92garg
# thalkarpranay
# shrey.tanchak
# efrainlyu
# food_crush_foodie
# suyashomer101
# syed.matiullah.942
# lovehoodblog
# sh.alini3644
# khushbooks
# wethe.foodies
# pankajanand
# the_actual_siddharathsehdev
# foodie____goodie
# suyeshakhanijao
# landscapespretty0
# vj93
# vrds.org123
# irfan.qureshi.0602
# far_racer_o93
# ashmita.iyer
# sapphai
# mr.dpk.0
# imdiyadutta
# 1_nitin_official__302
# moody_artisogram
# aditnegi
# s4soniya
# deepakkapoor534
# carzy4uh
# cooking_with_gohar
# table_lust
# nishant_me
# musaafi.rr
# saritamakeovers
# dipanshu0330
# itsfaraali
# official_rajput_shab_ji_
# foodiethefoodlover
# shraddhai_
# exausted_72
# nainakanagat
# foxy_bunny_45
# sidd_attitudes07
# nida.desai
# harjinderbharapur
# sonidisouza
# unpredictableride
# sweet.2727
# goodfoodgoodmood85
# priyankathakur4089
# _tusharvashisht
# bhargav_krishna274
# preetiijha
# cut.plate
# yardiashish
# cafenook.hyd
# jiyatahlani
# fernandez_inc
# its__fardeen_s5
# mohanrck
# amake_25
# anne_puech
# duakhan1879
# jot.112020
# devilgupta960
# alvinbrodanishrokh8
# hansika_shiny_15
# pitstop_kitchen
# samriddhi05656
# gypseapants
# zameeroking
# aditya93058
# gaja_rkahalwa
# my_name_is___._______
# refectionsthejuicebar
# sidherseema
# foodieperson100
# kanchan_178
# the_prabha_international
# misba.aamir
# pancy656
# freedoms39
# sruthi_en
# aprilyears
# shivendrajput13
# dein_foodblock2021
# amulyav_
# solopasta4
# imkalbasu
# jaishalamit
# sakshi_jadaun
# just_shree_19
# richa.sinha1706
# _khaadya_padarth
# wenqi.yin
# foodmashita
# _sh0ts0flife__
# kokila_jane_ramu_65
# official_kfc._
# forkedheels
# tanu.bedi.9256
# rajani.nikhare.35
# snigdha.mishra
# lemonandpeels
# gsdietculture
# munchh_better
# xl753159
# the_amazin_graze
# ankush.bhat1
# sriethiraj
# abhik_das_sasati
# artpoolstore
# goelkanika6
# thebiglifejournal
# kitchenstar2021
# snehaej
# _foodjunction_
# ani_cdote
# _jyoti_you_can_
# hestanai_dia_pantos
# daswanigautam
# anshika_singh.6
# jainitishree06
# pratz.261194qwer
# jamurbatmanfoodantikorup
# indianajazz
# bharatkadam
# garima1905
# bavssss_
# nagsanjeev
# utsav.nmh
# vishakha0903
# rchadha2002
# asan123gmail.com_
# vaibhav3131
# djdushyantjoshi
# riyakaur0005
# chinnu_0426
# plates_of_flavours_0113
# rsakshi96
# thetravelcrunch.ttc
# zara_ayaan.8
# qu33n_68
# samiullah_zalaal
# mon.petite.patisserie
# jollypatta
# queen_of_the_hell_123
# mrunknown9677
# dips2220
# chunmuntuku
# pankhuri4046
# umasaraf_bittu
# ritika_yadav_pagalchori
# the_diningstories
# keshav8866
# sreevatsakota
# dabosreemondal
# foodiesletsconnect
# nihal___agarwal__
# foodstruc
# indianalchemy.in
# sohiniskitchen
# rj09_king_of_kailash______
# masalawokkolkata
# devalkapoor9
# veronicagoenkaart
# foodmeupofficial
# krishchhatwal
# buddy_sayandip
# sascha_uma
# luchi.aka.puri.aludum
# jaat_bl
# thelifestyletreasure
# satvik.sehgal
# food.for.feed
# akshaybhosale351
# pallavishankar_kr_
# sornalisantra
# gharkeswad
# arif_fitnesss
# sanjana_kulkarnijun19
# the_brothers_fusion_cafe
# onewrapdigitalsolutions
# rakeshkishore
# avishidubey2502
# shopudiet
# __butterfly97__
# deepabhardwaj
# its_kalpesh_rajput
# ninadatre
# shashi_shahane
# ra3y__e7sas
# ___books_way99x
# delectalicious
# mahimaaprampaar
# irohanb13
# azadsmart06
# ____kallu___
# eight_one_nine
# shashihautmondemrsindia2020
# dubeyji_456
# ashwin.m1500
# shine9295
# siddharthsingh_tanwar
# horadeeksha
# shwettarai24
# parulrawat42
# chefsati
# manishmishra8907
# the_jalebi_lover
# pink.i8038
# avikdas18120
# ayesha.aljalef
# the_jharkhand_wala
# lizlizkimm
# youviegaba
# dr.nishhi.gupta.3192
# flavourofindia_gallarate
# umashankar4479
# canadian_parinde
# kumar_naveen095
# bittu_singh_______
# ohh.foodie19
# foodiess_____
# mukesh.bajaj83
# shhobhitt
# therealfoodhabits
# whatdoidowitheachday
# kiani_writes
# rachit_4531
# atul_sharma_1193
# foifoods
# repar_boy_
# foodie._.dudie
# rizana_salim
# mytaste2021
# skhushboo180
# iam_aditideshmukh
# asianfunindia
# sairaj.n
# ninaskitchen_01
# prasun.halder.589
# shijin232
# lordsiddharthsabikhi
# nagendra6481
# streetfood_magic
# preetam05_98
# marsala.foodconnoisseurs
# veerjataheer
# itspreetkaur
# rushabh_waghela
# sokneeoh
# sjohnson_1212
# mayankmasand
# noodles.bar
# anas_el_amr
# kgbharathm
# bhavani_dacha
# tilaktikak
# sahil_malek1234
# thakurinsta02
# pariya_aziz1996
# fajitaco
# dabba_feast
# mr_zeeshan_m11
# inside_foods_world
# rinakhandelwal156
# mom.club.india
# yati_tyagii
# ritvickbargotra
# rebellious_quirky
# amulya__offical
# aakashslashsharmeyyy
# ranusingh808
# roostercart_07
# keerrtooz
# samruddhi_____21
# taniya_capric
# saburikhurana
# gudimettaindira
# edwinwilson_from.earth
# shoe.less
# pranav123.solanki
# roshan_boutique

# %%
driver.back()
driver.back()

# %% [markdown]
# soDELhi

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("sodelhi")                                              #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting sodelhi
b.click() #clicking it to open  the profile of "sodelhi"

followers_button = wait.until(EC.presence_of_element_located((By.XPATH,'//a[contains(@class,"-nal3")]'))) #follower button search
followers_button.click()   #click on followers button
time.sleep(2)
while True:
    f= driver.find_element_by_class_name('isgrP') #locating the #follower page
    f.click()
    driver.find_element_by_tag_name('body').send_keys(Keys.END)  #moving end of document 
    follower= driver.find_elements_by_xpath('//div[@class = "isgrP"]/ul/div/li') #follower list
    if len(follower)>=500: #checking whether the count is greated then 500 or not
        break

li = []
j=0
sodelhi= []
for i in follower:                                                                  
    data = BeautifulSoup(i.get_attribute('innerHTML'),'html')                         #to get the name of follower             
    li.append(data.a['href'].split('/')[1])                                           #adding name in list
    sodelhi.append(data.a['href'].split('/')[1])
    j+=1
    if j==500:                                                                        #only top 500 follower
        break
for i in sodelhi:#running a loop to display all the to 500 followers
    print(i)
# Out:
# thetomara
# meetusahdev
# swathy.ammus.712
# x_vivid_snap_x
# nswtravelogue
# __adarsh._.pandit
# iamannirudh
# lakshay_gupta77
# the_baldman_
# anushee.agarwal
# ipshita.adhikary
# saloni299
# ishreyakumari
# khileshpratab
# nileshkumar70878
# akashdeepsingh_99
# ananyaaaa_09
# sweetscape16
# saarthak.84
# kanishq_basoya_dellhii0001
# nishu.du
# saudamini_gupta_
# atwal_ji318
# aashima_2207
# i.utkarshpandey
# meesha_blogs
# vedangisharmaa_
# shub_ham873
# gylbhavana
# aranya.03
# theperspicaciouscompanion
# kr_akash7
# itzz_me_asif_786
# mak_loveuse12
# _mr_d_i_l_
# gem_leonine
# pri_to19
# naveen_s009
# aqsht
# anuj_raj_
# ar.vin5502
# _rishabhbhadauria_
# aasiyahashraf
# _t_ir_th_a_
# sara_____francina
# paramjeet_happy
# sheetalnagrath
# samarpan.mukherjee
# mr.md_abid
# gauravsain09
# richa.verma.7921
# shweta_.kaushik
# nirmala123sindhu
# ritik_rajput_0009
# kaif_alvi_007
# ritikaaa.nischal
# anjali_fitlift
# vishanktomar
# nupurprakash1992
# naren040110
# enlightedrjjain
# joshidurgesh649
# anurag888
# parul.kashyap.10
# shivaniichand
# nk9006
# yuktaa_20
# boxboyamit
# quik.tile
# the.maverick10
# ___.shanu.______
# a_vi_123
# artist_.sunny
# jahanvisinghtarkar
# food.maniac2020
# i_pavan_jain
# umair__33
# ashish.1604
# aniket_5302
# tee.pvtee
# nehel_10
# itanyatyagi
# deepshikha019
# himani.khan
# sidharthverma.1
# ___hahahaa_____
# my.name.momo
# farooknatheera
# rushed31
# anusshayy_1
# adijadaun
# manik_1987b
# foodtrail._
# sangita.gupta974
# fashionista_22822
# roxx_abhas
# lewa.graphic
# amann55800
# mandeepsaluja__
# beingtaleebhasan
# pruthvirajelluru
# abdoznh
# divyanshujhaaa
# aakash10101
# nitinchadda1234
# rajatnakra
# dr_vibhuti
# nottinghillbakes
# advektakalra
# dreamer_wizard_
# jainc1979
# jinu6470
# kaniiisshka
# colours_of_life.11
# wellwell._.1
# sageandfolly
# msaini_02
# anuraja95
# samchawla
# _ayushi.kumari_
# anuj_attal
# ashwanibikal
# go.food.yourself
# seminalalanijiwani
# utkarshkumarroy868
# thetrueetales
# darshanbaid22
# cutelittlepockets_
# shraddha_kum
# payu0206
# saurabhyadav.y2k
# nikhilgulati92
# mahisharma746
# sanskritimishra_
# mahimaalohia
# i_jaydev_limbachiya
# khush.bhandari
# tabishsultan900
# vineethchouhan
# foodpoint.delhi
# neha_sharm_20
# juhirajput07
# shilpygaurav
# hellya_16
# qu.8253
# leewayrestro
# vishal121634
# ishiika_gupta
# gaurav3.14159265358979
# photographeramanjain
# kakkar_sahil
# pratham4363
# young_coded_gh
# hyperactivedreamer
# likhmaramkhicharratasar
# prabir_kumar_pal7
# gurri_kaur2796
# ipranav009
# akshat_tickoo
# tanvi77440
# isatyambarmase
# lucky_singh655
# mdlukmankhan7
# thedelhifoodiee_
# prashant.451
# srayota
# ruchumehta2
# kdpatel375
# amitranaaaa
# ruchik_sawhney
# kirtiagarwal_qm
# amrit_kaur_matharu
# shubhi_9725
# _yashab_khan
# prernasharma___
# la_messop
# mansha_mahajan_
# mrs_khan125
# _.1000_pieces._
# umasaraf_bittu
# mister.ritchi.s.life
# nupurkalra4
# sharmakibetiji
# aykaycandids
# simpy_yadav_27
# qaz51756070
# hasansaba10
# indiatravelcaptures
# iamwellandgoodeepak
# surabhi_shree9
# modilshad.modilshad.754
# bruce.micheal20
# wrapway_official
# _firelord__
# sushmasangwan
# esoteric.af_
# eesha_anand_
# pratishtha.pvt_
# this_is_mayanksingh
# ilma_rajputttt
# kitchenaditis
# rashii._.singh
# sudeeptaaa
# akhilverma929
# panditjikilemontea
# knowa_boutyourself
# gurdeep.singh_rana
# fizanaaz271
# nigam__yash
# shivanshu_shiv
# paaksadhna_cooking_is_yoga
# pranshubansal_pb
# masakali_ii
# nazimsheikh519
# aakashagrawal_official
# shalini.missy
# mankhushjha1996
# tarun97rao
# nikhilsearch23
# nami__jain
# rohitsharma61
# wasim_saifi_
# ritikaakhatri
# mdazam.khan.969952
# ajjubhai__07
# bk.ok.1840
# _this_is_ankush_
# abbysaxenaa
# kirtisharma0694
# 7777777mahakaal
# akanksha_akku
# simran_choudhary18
# chouhan.shalini
# sam_earth22
# prashantsoni1308
# usn_2107
# ruchika_kv
# mohsin_bae
# aasthaasardana
# sayohere
# sanchitmadan_
# sahil_bhai439
# rajeshelmusico
# entewayanad._
# blushing_littlefish
# himanshibanka
# ishnofficial
# tanishkaofficial_
# jhaprabhs21
# v_i_v_e_k_05_05
# foodie_girl37
# devharjani
# poonam_1singh
# divyat_
# harvinderkaur726
# sanjeevanisrivastav118
# dottedi_bangalore
# hanuman21soni
# robby0074
# offical_king_nikhil_
# asan.solfoodie
# shubham.sr4
# shripriya15
# the_stoned.stoner
# drhs_27
# faizanfk9634
# sanchit_mathur
# mohsin2202
# suryaansh111
# momos_at_avengers
# himani_manral22
# signs_and_furnishing
# rehman.khan.568
# obscure.facts
# _pooja_jhaa_
# deveshjoshi_ddesigner
# saketjaipuria
# k.abhi7227
# demythifyerotica
# bhangaleharshwardhan
# mayank_nahar4326
# kalpana.2k3
# vija.ykumar1025
# himanshusharmaeee
# dixit_siddhartha
# shinchan_lover_830
# lol11zz22
# rishabhagarwals
# simmmaarrr
# classic_cake_bake
# ritika_mp_lover
# shraddhakapoorfanpage123
# parveenpawar09
# befikrey_parindey
# aditayaseghal
# _girly_thing_s
# sakshiarya441
# _deepalisaini_
# r.ika_09
# anshupandey864
# _a_d_h_i_k
# ikarannair
# bagpack_wid_smitha
# nutritionlifemx
# sharma92sachin
# mairainestagliarihoff
# jalmeidamelo
# __groversahab__
# tealover7054
# niyti_
# hebaarshad
# shivanisuman97
# notey_girl457
# satvik__k
# ibnsadiqbpr
# kulkarni.16shruti
# iam_sagittarius_girl
# aayushgupta323
# vicmanitt
# niteshkau2
# sanyasana
# manojmehra_
# unseenfoodie
# pranayy4real
# bhavyagupta99
# khan__faizaan
# nirajku7954
# yourboiashkr
# iamluckysharma11
# nikki.barar12
# _m.anurag10
# yaaaaaaaaaarrr
# lakshyasuneja
# avni.2002
# vansh6803
# hairy_girl18
# saini_nation
# ankahe_shabd
# jajerephotography
# i_anjalakhader
# i.pradumnsingh
# _.hars.hita._
# s.nblog
# sonikalalit
# kanimozhiie
# juneja.lakshay
# label_me_official
# vnktsshhhh
# anshuldhingra
# mohitweets
# samanvithathalla
# ps_piyush02
# k.a.v.y.a.22
# baesilandthyme
# shivam_maalhotra
# varunahooja
# saman_zehra_sz
# _insta_likefollowers
# onewithbig_glasses
# khalish1985
# antiquewarehouseofficial
# paankhiii
# dhawan.p
# utkarsh3312
# dimpysingh95
# mall_aria
# rarora64
# mayank_singla507
# bhoomigyan
# saddamqureshi.sq
# sanchit0081
# montyanil
# 2photo_phactory5
# _mugen21_
# shiikhaar
# deekay8088
# inspire_explore_create
# beingg_sane
# priyaankjain
# iamvikas__
# 1212jayesh
# akaa.mystic
# official_arav111
# anuvijeth__anu_________
# vijay.kr1010
# rakesh_mantodi
# gurittoo
# iamssiddiqui
# vikas.kankani
# princessnehakate
# mandal_prince24
# gaurav_shepheard
# akshaykhatri012
# surya_rathore_78
# er_d.k.lucknow
# indusrivastava_14
# bowlzncomboz
# gaur_sourav
# sharique_quazi05
# abhineo
# akshitgoyal96
# aakashrajput7670
# sagarsinhmar
# foodiesletsconnect
# official_isha_katyal
# rahul_dehai_07
# denubeautycare_surat
# official_bish9ii_29
# justhungerthings
# n_latikaa
# carolcastro9875
# vishaldangiofficial
# monu_9329
# alokathletes_100m_200msprinter
# sumitphougat
# purnima.chaubey
# ankey.ta
# golu.143143
# vvipul_2512
# __ayushi07
# garishma95
# bhawnamahara
# th_rps
# aman_10___
# _asha_ash_
# sheenampahwa
# sofia080808
# drchandtewatiya
# sagarwave107
# guy_from_the_mountains1
# anshu.0310
# _a.rpit_a.s_ondhiya7519
# aditya0619
# priyanka._.dhar
# 11hardik
# ann_preshita
# malachitepr
# prinks_bisht
# boldbibi
# niharikabhadauriaa
# oldmonk___
# _anujdubey_
# famusbo
# parulkochar17
# foodbyamik
# _the_shavez
# _sheena.bhatia_
# purnika.sharma
# _iamrajgaurav
# 08dayasingh
# ar.sandeep_kumar
# sargun9
# _.mokshita
# sheetalshekhawatt
# _isha.raj
# anuxkriti
# the.dramatist
# singhpushpender4277
# nabhanya_s
# s_u_n_i_l_2_00
# shivam.keshri.5477
# heydushhh
# samos.cha
# its_officialdipanshu_
# arpit_mohnot
# __pradeep__1999
# pradeep.chinu13
# i_need_new_haters._the_old_one
# _iamshradz
# isoorbhiii
# shinearora94
# shambhavi_arora_
# ijassmanak_for_shariyan
# yashubhpandit
# pappidihatti
# deepsaggu1
# wronglyright
# rrana2812
# sugandhichandwani
# je.nny431
# __apoorva__
# ankit_sharmaa____
# sanchitgoel08
# arhan.anshri
# humanslothbear
# rishichoudhary208
# nishantssbhatia
# mayur__chouksey
# rony69wastaken
# reetika_0000
# adila__t
# nxxeef
# manyu0723
# meghasawe1979
# belwalpank
# kobeegrill20
# weworewhat_1331
# study_for_success_
# _yashvi_0609
# the_rjpj

# %%
driver.back()
driver.back()

# %% [markdown]
# B. Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("foodtalkindia")                                             #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting foodtalkindia
b.click() #clicking it to open  the profile of "foodtalkindia"
followers_button = wait.until(EC.presence_of_element_located((By.XPATH,'//a[contains(@class,"-nal3")]'))) #follower button search
        #da=BeautifulSoup(driver.page_source,'lxml')
        #allfoll=int(da.find_all(class_='g47SY')[1]['title'].replace(',',''))
followers_button.click()   #click on followers button
time.sleep(2)
while True:
    f= driver.find_element_by_class_name('isgrP') #locating the #follower page
    f.click()
    driver.find_element_by_tag_name('body').send_keys(Keys.END)  #moving end of document
    follower= driver.find_elements_by_xpath('//div[@class = "isgrP"]/ul/div/li') #follower list
    if len(follower) >= 500:
        break  #checking whether the count is greated then 500 or not
    

li = [] #creating an empty list
j=0 #creating this variable to keep track of the count
names = [] #emptylist for storing the name of the user
for i in follower:
    data = BeautifulSoup(i.get_attribute('innerHTML'),'html')
    li.append(data.a['href'].split('/')[1])
    names.append(data.a['href'].split('/')[1])
    j+=1
    if j==500:
        break


i=0 #this variable I have created to have the index value throungh which we can determine the name of the user
for p in follower:
    try:
        data = BeautifulSoup(p.get_attribute('innerHTML'),'html')
        if data.button.text=="Following":   #only printing that follwoing but don't follow u back 
            print(names[i])
        
        i=i+1

    except StaleElementReferenceException:
        continue
# Out:
# ranjit8445

# %% [markdown]
# 7. Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -

# %% [markdown]
# A. If You have already seen the story.
#
# B. Or The user has no story.
#
# c. Or View the story if not yet seen.

# %%
driver.back()
driver.back()

# %%
search=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]') #loacting the search box
search.send_keys("coding.ninjas")                                             #sending values for searching
b = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'yCE8d')))     #selecting coding.ninjas
b.click() #clicking it to open  the profile of "coding.ninjas"
time.sleep(2)
try:
    #i have compared the width of the canvas class when it is seen its value is 208 and have different value when its is not seen
    if int(driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]/canvas').get_attribute('height'))==208:
        print('You have already seen the story!')#printing the status
    elif int(driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]/canvas').get_attribute('height'))!=208:
        print("You have not seen the story and you will be redirected to the status page")#printing the status
        driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]').click()#redirecting to the status page to view the status
except NoSuchElementException:
    print('The user has no story!')
# Out:
# You have already seen the story!
